# %% [markdown]
# Load the model into a more intuitive graph structure using `OsimGraph`:

# %%
from src.osim_graph import OsimGraph

model_path = "models/RajagopalLaiUhlrich2023.osim"

graph = OsimGraph.from_file(model_path)
# Out:
# 2025-08-13 10:27:39.311 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_tilt range: (-1.57079633, 1.57079633)
# 2025-08-13 10:27:39.313 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_list range: (-1.57079633, 1.57079633)
# 2025-08-13 10:27:39.313 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_rotation range: (-6.283185307179586, 6.283185307179586)
# 2025-08-13 10:27:39.314 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_tx range: (-50.0, 50.0)
# 2025-08-13 10:27:39.314 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_ty range: (-1.0, 2.0)
# 2025-08-13 10:27:39.315 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pelvis_tz range: (-3.0, 3.0)
# 2025-08-13 10:27:39.317 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint ground_pelvis connects ground and pelvis
# 2025-08-13 10:27:39.317 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_flexion_r range: (-0.52359878, 2.0943951)
# 2025-08-13 10:27:39.318 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_adduction_r range: (-0.87266463, 0.52359878)
# 2025-08-13 10:27:39.318 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_rotation_r range: (-0.6981317, 0.6981317)
# 2025-08-13 10:27:39.318 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint hip_r connects pelvis and femur_r
# 2025-08-13 10:27:39.319 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate knee_angle_r range: (0.0, 2.44346095279206)
# 2025-08-13 10:27:39.319 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint walker_knee_r connects femur_r and tibia_r
# 2025-08-13 10:27:39.320 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate knee_angle_r_beta range: (-99999.9, 99999.9)
# 2025-08-13 10:27:39.321 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint patellofemoral_r connects femur_r and patella_r
# 2025-08-13 10:27:39.322 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate ankle_angle_r range: (-0.8726646259971648, 0.8726646259971648)
# 2025-08-13 10:27:39.323 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint ankle_r connects tibia_r and talus_r
# 2025-08-13 10:27:39.323 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate subtalar_angle_r range: (-0.610865238198015, 0.610865238198015)
# 2025-08-13 10:27:39.323 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint subtalar_r connects talus_r and calcn_r
# 2025-08-13 10:27:39.324 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate mtp_angle_r range: (-0.7853981633974483, 0.52359878)
# 2025-08-13 10:27:39.324 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint mtp_r connects calcn_r and toes_r
# 2025-08-13 10:27:39.325 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_flexion_l range: (-0.52359878, 2.0943951)
# 2025-08-13 10:27:39.325 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_adduction_l range: (-0.87266463, 0.52359878)
# 2025-08-13 10:27:39.325 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate hip_rotation_l range: (-0.6981317, 0.6981317)
# 2025-08-13 10:27:39.326 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint hip_l connects pelvis and femur_l
# 2025-08-13 10:27:39.326 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate knee_angle_l range: (0.0, 2.44346095279206)
# 2025-08-13 10:27:39.327 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint walker_knee_l connects femur_l and tibia_l
# 2025-08-13 10:27:39.328 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate knee_angle_l_beta range: (-99999.9, 99999.9)
# 2025-08-13 10:27:39.329 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint patellofemoral_l connects femur_l and patella_l
# 2025-08-13 10:27:39.329 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate ankle_angle_l range: (-0.8726646259971648, 0.8726646259971648)
# 2025-08-13 10:27:39.330 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint ankle_l connects tibia_l and talus_l
# 2025-08-13 10:27:39.332 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate subtalar_angle_l range: (-0.610865238198015, 0.610865238198015)
# 2025-08-13 10:27:39.333 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint subtalar_l connects talus_l and calcn_l
# 2025-08-13 10:27:39.334 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate mtp_angle_l range: (-0.7853981633974483, 0.52359878)
# 2025-08-13 10:27:39.334 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint mtp_l connects calcn_l and toes_l
# 2025-08-13 10:27:39.335 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate lumbar_extension range: (-1.57079633, 1.57079633)
# 2025-08-13 10:27:39.335 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate lumbar_bending range: (-1.57079633, 1.57079633)
# 2025-08-13 10:27:39.335 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate lumbar_rotation range: (-1.57079633, 1.57079633)
# 2025-08-13 10:27:39.336 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint back connects pelvis and torso
# 2025-08-13 10:27:39.336 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_flex_r range: (-10.0, 10.0)
# 2025-08-13 10:27:39.337 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_add_r range: (-10.0, 10.0)
# 2025-08-13 10:27:39.338 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_rot_r range: (-10.0, 10.0)
# 2025-08-13 10:27:39.339 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint acromial_r connects torso and humerus_r
# 2025-08-13 10:27:39.339 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate elbow_flex_r range: (0.0, 2.618)
# 2025-08-13 10:27:39.340 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint elbow_r connects humerus_r and ulna_r
# 2025-08-13 10:27:39.340 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pro_sup_r range: (0.0, 2.09)
# 2025-08-13 10:27:39.341 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint radioulnar_r connects ulna_r and radius_r
# 2025-08-13 10:27:39.341 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint radius_hand_r connects radius_r and hand_r
# 2025-08-13 10:27:39.342 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_flex_l range: (-10.0, 10.0)
# 2025-08-13 10:27:39.342 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_add_l range: (-10.0, 10.0)
# 2025-08-13 10:27:39.343 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate arm_rot_l range: (-10.0, 10.0)
# 2025-08-13 10:27:39.343 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint acromial_l connects torso and humerus_l
# 2025-08-13 10:27:39.343 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate elbow_flex_l range: (0.0, 2.618)
# 2025-08-13 10:27:39.344 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint elbow_l connects humerus_l and ulna_l
# 2025-08-13 10:27:39.344 | DEBUG    | src.osim_graph:create_rigid_graph:146 - Coordinate pro_sup_l range: (0.0, 2.09)
# 2025-08-13 10:27:39.344 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint radioulnar_l connects ulna_l and radius_l
# 2025-08-13 10:27:39.345 | DEBUG    | src.osim_graph:create_rigid_graph:156 - Joint radius_hand_l connects radius_l and hand_l
# 2025-08-13 10:27:39.345 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addbrev_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AB_at_femshaft_r']
# 2025-08-13 10:27:39.346 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addlong_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AL_at_femshaft_r']
# 2025-08-13 10:27:39.346 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagDist_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AMdist_at_femshaft_r']
# 2025-08-13 10:27:39.346 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagIsch_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AMisch_at_condyles_r']
# 2025-08-13 10:27:39.347 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagMid_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AMmid_at_femshaft_r']
# 2025-08-13 10:27:39.347 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagProx_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['AMprox_at_femshaft_r']
# 2025-08-13 10:27:39.347 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle bflh_r attaches to bodies ['pelvis', 'tibia_r'] and wraps []
# 2025-08-13 10:27:39.347 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle bfsh_r attaches to bodies ['femur_r', 'tibia_r'] and wraps ['BF_at_gastroc_r']
# 2025-08-13 10:27:39.348 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle edl_r attaches to bodies ['tibia_r', 'calcn_r', 'toes_r'] and wraps []
# 2025-08-13 10:27:39.348 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle ehl_r attaches to bodies ['tibia_r', 'calcn_r', 'toes_r'] and wraps []
# 2025-08-13 10:27:39.349 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle fdl_r attaches to bodies ['tibia_r', 'calcn_r', 'toes_r'] and wraps []
# 2025-08-13 10:27:39.349 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle fhl_r attaches to bodies ['tibia_r', 'calcn_r', 'toes_r'] and wraps []
# 2025-08-13 10:27:39.349 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle gaslat_r attaches to bodies ['femur_r', 'calcn_r'] and wraps ['GasLat_at_shank_r', 'GasLat_at_condyles_r']
# 2025-08-13 10:27:39.350 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle gasmed_r attaches to bodies ['femur_r', 'calcn_r'] and wraps ['GasMed_at_shank_r', 'GasMed_at_condyles_r']
# 2025-08-13 10:27:39.350 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax1_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['Gmax1_at_pelvis_r']
# 2025-08-13 10:27:39.351 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax2_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['Gmax2_at_pelvis_r']
# 2025-08-13 10:27:39.351 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax3_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['Gmax3_at_pelvis_r']
# 2025-08-13 10:27:39.352 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed1_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.352 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed2_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.352 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed3_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.353 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin1_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.353 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin2_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.353 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin3_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.354 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle grac_r attaches to bodies ['pelvis', 'tibia_r'] and wraps ['GR_at_condyles_r']
# 2025-08-13 10:27:39.356 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle iliacus_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['IL_at_brim_r']
# 2025-08-13 10:27:39.357 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle perbrev_r attaches to bodies ['tibia_r', 'calcn_r'] and wraps []
# 2025-08-13 10:27:39.358 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle perlong_r attaches to bodies ['tibia_r', 'calcn_r'] and wraps []
# 2025-08-13 10:27:39.358 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle piri_r attaches to bodies ['pelvis', 'femur_r'] and wraps []
# 2025-08-13 10:27:39.358 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle psoas_r attaches to bodies ['pelvis', 'femur_r'] and wraps ['PS_at_brim_r']
# 2025-08-13 10:27:39.359 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle recfem_r attaches to bodies ['pelvis', 'patella_r', 'tibia_r'] and wraps ['KnExt_at_fem_r']
# 2025-08-13 10:27:39.359 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle sart_r attaches to bodies ['pelvis', 'femur_r', 'tibia_r'] and wraps []
# 2025-08-13 10:27:39.360 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle semimem_r attaches to bodies ['pelvis', 'tibia_r'] and wraps ['SM_at_condyles_r']
# 2025-08-13 10:27:39.360 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle semiten_r attaches to bodies ['pelvis', 'tibia_r'] and wraps ['ST_at_condyles_r']
# 2025-08-13 10:27:39.361 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle soleus_r attaches to bodies ['tibia_r', 'calcn_r'] and wraps []
# 2025-08-13 10:27:39.361 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tfl_r attaches to bodies ['pelvis', 'femur_r', 'tibia_r'] and wraps []
# 2025-08-13 10:27:39.361 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tibant_r attaches to bodies ['tibia_r', 'calcn_r'] and wraps []
# 2025-08-13 10:27:39.363 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tibpost_r attaches to bodies ['tibia_r', 'calcn_r'] and wraps []
# 2025-08-13 10:27:39.363 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vasint_r attaches to bodies ['femur_r', 'patella_r', 'tibia_r'] and wraps ['KnExt_at_fem_r']
# 2025-08-13 10:27:39.363 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vaslat_r attaches to bodies ['femur_r', 'patella_r', 'tibia_r'] and wraps ['KnExtVL_at_fem_r']
# 2025-08-13 10:27:39.364 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vasmed_r attaches to bodies ['femur_r', 'patella_r', 'tibia_r'] and wraps ['KnExt_at_fem_r']
# 2025-08-13 10:27:39.364 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addbrev_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AB_at_femshaft_l']
# 2025-08-13 10:27:39.364 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addlong_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AL_at_femshaft_l']
# 2025-08-13 10:27:39.365 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagDist_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AMdist_at_femshaft_l']
# 2025-08-13 10:27:39.365 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagIsch_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AMisch_at_condyles_l']
# 2025-08-13 10:27:39.365 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagMid_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AMmid_at_femshaft_l']
# 2025-08-13 10:27:39.366 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle addmagProx_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['AMprox_at_femshaft_l']
# 2025-08-13 10:27:39.366 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle bflh_l attaches to bodies ['pelvis', 'tibia_l'] and wraps []
# 2025-08-13 10:27:39.366 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle bfsh_l attaches to bodies ['femur_l', 'tibia_l'] and wraps ['BF_at_gastroc_l']
# 2025-08-13 10:27:39.367 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle edl_l attaches to bodies ['tibia_l', 'calcn_l', 'toes_l'] and wraps []
# 2025-08-13 10:27:39.367 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle ehl_l attaches to bodies ['tibia_l', 'calcn_l', 'toes_l'] and wraps []
# 2025-08-13 10:27:39.367 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle fdl_l attaches to bodies ['tibia_l', 'calcn_l', 'toes_l'] and wraps []
# 2025-08-13 10:27:39.368 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle fhl_l attaches to bodies ['tibia_l', 'calcn_l', 'toes_l'] and wraps []
# 2025-08-13 10:27:39.368 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle gaslat_l attaches to bodies ['femur_l', 'calcn_l'] and wraps ['GasLat_at_shank_l', 'GasLat_at_condyles_l']
# 2025-08-13 10:27:39.368 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle gasmed_l attaches to bodies ['femur_l', 'calcn_l'] and wraps ['GasMed_at_shank_l', 'GasMed_at_condyles_l']
# 2025-08-13 10:27:39.369 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax1_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['Gmax1_at_pelvis_l']
# 2025-08-13 10:27:39.369 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax2_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['Gmax2_at_pelvis_l']
# 2025-08-13 10:27:39.369 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmax3_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['Gmax3_at_pelvis_l']
# 2025-08-13 10:27:39.370 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed1_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.370 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed2_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.370 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmed3_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.371 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin1_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.371 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin2_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.371 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle glmin3_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.372 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle grac_l attaches to bodies ['pelvis', 'tibia_l'] and wraps ['GR_at_condyles_l']
# 2025-08-13 10:27:39.372 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle iliacus_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['IL_at_brim_l']
# 2025-08-13 10:27:39.372 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle perbrev_l attaches to bodies ['tibia_l', 'calcn_l'] and wraps []
# 2025-08-13 10:27:39.373 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle perlong_l attaches to bodies ['tibia_l', 'calcn_l'] and wraps []
# 2025-08-13 10:27:39.373 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle piri_l attaches to bodies ['pelvis', 'femur_l'] and wraps []
# 2025-08-13 10:27:39.374 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle psoas_l attaches to bodies ['pelvis', 'femur_l'] and wraps ['PS_at_brim_l']
# 2025-08-13 10:27:39.374 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle recfem_l attaches to bodies ['pelvis', 'patella_l', 'tibia_l'] and wraps ['KnExt_at_fem_l']
# 2025-08-13 10:27:39.376 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle sart_l attaches to bodies ['pelvis', 'femur_l', 'tibia_l'] and wraps []
# 2025-08-13 10:27:39.377 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle semimem_l attaches to bodies ['pelvis', 'tibia_l'] and wraps ['SM_at_condyles_l']
# 2025-08-13 10:27:39.377 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle semiten_l attaches to bodies ['pelvis', 'tibia_l'] and wraps ['ST_at_condyles_l']
# 2025-08-13 10:27:39.378 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle soleus_l attaches to bodies ['tibia_l', 'calcn_l'] and wraps []
# 2025-08-13 10:27:39.378 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tfl_l attaches to bodies ['pelvis', 'femur_l', 'tibia_l'] and wraps []
# 2025-08-13 10:27:39.378 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tibant_l attaches to bodies ['tibia_l', 'calcn_l'] and wraps []
# 2025-08-13 10:27:39.379 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle tibpost_l attaches to bodies ['tibia_l', 'calcn_l'] and wraps []
# 2025-08-13 10:27:39.379 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vasint_l attaches to bodies ['femur_l', 'patella_l', 'tibia_l'] and wraps ['KnExt_at_fem_l']
# 2025-08-13 10:27:39.379 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vaslat_l attaches to bodies ['femur_l', 'patella_l', 'tibia_l'] and wraps ['KnExtVL_at_fem_l']
# 2025-08-13 10:27:39.380 | DEBUG    | src.osim_graph:create_muscle_graph:190 - Muscle vasmed_l attaches to bodies ['femur_l', 'patella_l', 'tibia_l'] and wraps ['KnExt_at_fem_l']
# 2025-08-13 10:27:39.380 | DEBUG    | src.osim_graph:find_path:233 - Path found between pelvis and femur_r: ['pelvis', 'femur_r']
# 2025-08-13 10:27:39.380 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addbrev_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.380 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addlong_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.381 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagDist_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.381 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagIsch_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.382 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagMid_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.382 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagProx_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.382 | DEBUG    | src.osim_graph:find_path:233 - Path found between pelvis and tibia_r: ['pelvis', 'femur_r', 'tibia_r']
# 2025-08-13 10:27:39.383 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle bflh_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.383 | DEBUG    | src.osim_graph:find_path:233 - Path found between femur_r and tibia_r: ['femur_r', 'tibia_r']
# 2025-08-13 10:27:39.383 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle bfsh_r crosses joints {'walker_knee_r'}
# 2025-08-13 10:27:39.384 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_r', 'calcn_r', 'toes_r'].
# 2025-08-13 10:27:39.384 | DEBUG    | src.osim_graph:find_path:233 - Path found between tibia_r and toes_r: ['tibia_r', 'talus_r', 'calcn_r', 'toes_r']
# 2025-08-13 10:27:39.385 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle edl_r crosses joints {'mtp_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.385 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_r', 'calcn_r', 'toes_r'].
# 2025-08-13 10:27:39.386 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle ehl_r crosses joints {'mtp_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.386 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_r', 'calcn_r', 'toes_r'].
# 2025-08-13 10:27:39.386 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle fdl_r crosses joints {'mtp_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.387 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_r', 'calcn_r', 'toes_r'].
# 2025-08-13 10:27:39.387 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle fhl_r crosses joints {'mtp_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.387 | DEBUG    | src.osim_graph:find_path:233 - Path found between femur_r and calcn_r: ['femur_r', 'tibia_r', 'talus_r', 'calcn_r']
# 2025-08-13 10:27:39.388 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle gaslat_r crosses joints {'walker_knee_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.390 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle gasmed_r crosses joints {'walker_knee_r', 'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.390 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax1_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.390 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax2_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.391 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax3_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.391 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed1_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.392 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed2_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.392 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed3_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.392 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin1_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.393 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin2_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.393 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin3_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.393 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle grac_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.394 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle iliacus_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.394 | DEBUG    | src.osim_graph:find_path:233 - Path found between tibia_r and calcn_r: ['tibia_r', 'talus_r', 'calcn_r']
# 2025-08-13 10:27:39.394 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle perbrev_r crosses joints {'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.395 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle perlong_r crosses joints {'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.395 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle piri_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.395 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle psoas_r crosses joints {'hip_r'}
# 2025-08-13 10:27:39.396 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'patella_r', 'tibia_r'].
# 2025-08-13 10:27:39.396 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle recfem_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.397 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'femur_r', 'tibia_r'].
# 2025-08-13 10:27:39.397 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle sart_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.397 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle semimem_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.397 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle semiten_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.398 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle soleus_r crosses joints {'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.398 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'femur_r', 'tibia_r'].
# 2025-08-13 10:27:39.398 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tfl_r crosses joints {'hip_r', 'walker_knee_r'}
# 2025-08-13 10:27:39.398 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tibant_r crosses joints {'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.399 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tibpost_r crosses joints {'subtalar_r', 'ankle_r'}
# 2025-08-13 10:27:39.399 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_r', 'patella_r', 'tibia_r'].
# 2025-08-13 10:27:39.399 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vasint_r crosses joints {'walker_knee_r'}
# 2025-08-13 10:27:39.399 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_r', 'patella_r', 'tibia_r'].
# 2025-08-13 10:27:39.400 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vaslat_r crosses joints {'walker_knee_r'}
# 2025-08-13 10:27:39.400 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_r', 'patella_r', 'tibia_r'].
# 2025-08-13 10:27:39.400 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vasmed_r crosses joints {'walker_knee_r'}
# 2025-08-13 10:27:39.400 | DEBUG    | src.osim_graph:find_path:233 - Path found between pelvis and femur_l: ['pelvis', 'femur_l']
# 2025-08-13 10:27:39.401 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addbrev_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.401 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addlong_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.401 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagDist_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.401 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagIsch_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.402 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagMid_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.402 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle addmagProx_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.402 | DEBUG    | src.osim_graph:find_path:233 - Path found between pelvis and tibia_l: ['pelvis', 'femur_l', 'tibia_l']
# 2025-08-13 10:27:39.402 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle bflh_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.403 | DEBUG    | src.osim_graph:find_path:233 - Path found between femur_l and tibia_l: ['femur_l', 'tibia_l']
# 2025-08-13 10:27:39.403 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle bfsh_l crosses joints {'walker_knee_l'}
# 2025-08-13 10:27:39.403 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_l', 'calcn_l', 'toes_l'].
# 2025-08-13 10:27:39.403 | DEBUG    | src.osim_graph:find_path:233 - Path found between tibia_l and toes_l: ['tibia_l', 'talus_l', 'calcn_l', 'toes_l']
# 2025-08-13 10:27:39.404 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle edl_l crosses joints {'mtp_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.404 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_l', 'calcn_l', 'toes_l'].
# 2025-08-13 10:27:39.404 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle ehl_l crosses joints {'mtp_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.404 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_l', 'calcn_l', 'toes_l'].
# 2025-08-13 10:27:39.405 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle fdl_l crosses joints {'mtp_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.405 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['tibia_l', 'calcn_l', 'toes_l'].
# 2025-08-13 10:27:39.406 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle fhl_l crosses joints {'mtp_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.406 | DEBUG    | src.osim_graph:find_path:233 - Path found between femur_l and calcn_l: ['femur_l', 'tibia_l', 'talus_l', 'calcn_l']
# 2025-08-13 10:27:39.407 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle gaslat_l crosses joints {'walker_knee_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.407 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle gasmed_l crosses joints {'walker_knee_l', 'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.407 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax1_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.408 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax2_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.408 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmax3_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.408 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed1_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.408 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed2_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.409 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmed3_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.409 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin1_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.409 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin2_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.409 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle glmin3_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.410 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle grac_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.410 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle iliacus_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.413 | DEBUG    | src.osim_graph:find_path:233 - Path found between tibia_l and calcn_l: ['tibia_l', 'talus_l', 'calcn_l']
# 2025-08-13 10:27:39.413 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle perbrev_l crosses joints {'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.413 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle perlong_l crosses joints {'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.413 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle piri_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.414 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle psoas_l crosses joints {'hip_l'}
# 2025-08-13 10:27:39.414 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'patella_l', 'tibia_l'].
# 2025-08-13 10:27:39.414 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle recfem_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.414 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'femur_l', 'tibia_l'].
# 2025-08-13 10:27:39.415 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle sart_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.415 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle semimem_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.415 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle semiten_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.415 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle soleus_l crosses joints {'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.416 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['pelvis', 'femur_l', 'tibia_l'].
# 2025-08-13 10:27:39.416 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tfl_l crosses joints {'walker_knee_l', 'hip_l'}
# 2025-08-13 10:27:39.416 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tibant_l crosses joints {'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.417 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle tibpost_l crosses joints {'subtalar_l', 'ankle_l'}
# 2025-08-13 10:27:39.417 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_l', 'patella_l', 'tibia_l'].
# 2025-08-13 10:27:39.417 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vasint_l crosses joints {'walker_knee_l'}
# 2025-08-13 10:27:39.417 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_l', 'patella_l', 'tibia_l'].
# 2025-08-13 10:27:39.418 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vaslat_l crosses joints {'walker_knee_l'}
# 2025-08-13 10:27:39.418 | WARNING  | src.osim_graph:find_path:210 - find_path currently only handles two bodies. Using first and last of ['femur_l', 'patella_l', 'tibia_l'].
# 2025-08-13 10:27:39.418 | DEBUG    | src.osim_graph:cache_muscle_crossings:264 - Muscle vasmed_l crosses joints {'walker_knee_l'}
# [info] Updating Model file from 40000 to latest format...
# [info] Loaded model RajagopalLaiUhlrich2023 from file models/RajagopalLaiUhlrich2023.osim
# [warning] Couldn't find file 'r_pelvis.vtp'.
# [warning] Couldn't find file 'l_pelvis.vtp'.
# [warning] Couldn't find file 'sacrum.vtp'.
# [warning] Couldn't find file 'r_femur.vtp'.
# [warning] Couldn't find file 'r_tibia.vtp'.
# [warning] Couldn't find file 'r_fibula.vtp'.
# [warning] Couldn't find file 'r_patella.vtp'.
# [warning] Couldn't find file 'r_talus.vtp'.
# [warning] Couldn't find file 'r_foot.vtp'.
# [warning] Couldn't find file 'r_bofoot.vtp'.
# [warning] Couldn't find file 'l_femur.vtp'.
# [warning] Couldn't find file 'l_tibia.vtp'.
# [warning] Couldn't find file 'l_fibula.vtp'.
# [warning] Couldn't find file 'l_patella.vtp'.
# [warning] Couldn't find file 'l_talus.vtp'.
# [warning] Couldn't find file 'l_foot.vtp'.
# [warning] Couldn't find file 'l_bofoot.vtp'.
# [warning] Couldn't find file 'hat_spine.vtp'.
# [warning] Couldn't find file 'hat_jaw.vtp'.
# [warning] Couldn't find file 'hat_skull.vtp'.
# [warning] Couldn't find file 'hat_ribs_scap.vtp'.
# [warning] Couldn't find file 'humerus_rv.vtp'.
# [warning] Couldn't find file 'ulna_rv.vtp'.
# [warning] Couldn't find file 'radius_rv.vtp'.
# [warning] Couldn't find file 'pisiform_rvs.vtp'.
# [warning] Couldn't find file 'lunate_rvs.vtp'.
# [warning] Couldn't find file 'scaphoid_rvs.vtp'.
# [warning] Couldn't find file 'triquetrum_rvs.vtp'.
# [warning] Couldn't find file 'hamate_rvs.vtp'.
# [warning] Couldn't find file 'capitate_rvs.vtp'.
# [warning] Couldn't find file 'trapezoid_rvs.vtp'.
# [warning] Couldn't find file 'trapezium_rvs.vtp'.
# [warning] Couldn't find file 'metacarpal2_rvs.vtp'.
# [warning] Couldn't find file 'index_proximal_rvs.vtp'.
# [warning] Couldn't find file 'index_medial_rvs.vtp'.
# [warning] Couldn't find file 'index_distal_rvs.vtp'.
# [warning] Couldn't find file 'metacarpal3_rvs.vtp'.
# [warning] Couldn't find file 'middle_proximal_rvs.vtp'.
# [warning] Couldn't find file 'middle_medial_rvs.vtp'.
# [warning] Couldn't find file 'middle_distal_rvs.vtp'.
# [warning] Couldn't find file 'metacarpal4_rvs.vtp'.
# [warning] Couldn't find file 'ring_proximal_rvs.vtp'.
# [warning] Couldn't find file 'ring_medial_rvs.vtp'.
# [warning] Couldn't find file 'ring_distal_rvs.vtp'.
# [warning] Couldn't find file 'metacarpal5_rvs.vtp'.
# [warning] Couldn't find file 'little_proximal_rvs.vtp'.
# [warning] Couldn't find file 'little_medial_rvs.vtp'.
# [warning] Couldn't find file 'little_distal_rvs.vtp'.
# [warning] Couldn't find file 'metacarpal1_rvs.vtp'.
# [warning] Couldn't find file 'thumb_proximal_rvs.vtp'.
# [warning] Couldn't find file 'thumb_distal_rvs.vtp'.
# [warning] Couldn't find file 'humerus_lv.vtp'.
# [warning] Couldn't find file 'ulna_lv.vtp'.
# [warning] Couldn't find file 'radius_lv.vtp'.
# [warning] Couldn't find file 'pisiform_lvs.vtp'.
# [warning] Couldn't find file 'lunate_lvs.vtp'.
# [warning] Couldn't find file 'scaphoid_lvs.vtp'.
# [warning] Couldn't find file 'triquetrum_lvs.vtp'.
# [warning] Couldn't find file 'hamate_lvs.vtp'.
# [warning] Couldn't find file 'capitate_lvs.vtp'.
# [warning] Couldn't find file 'trapezoid_lvs.vtp'.
# [warning] Couldn't find file 'trapezium_lvs.vtp'.
# [warning] Couldn't find file 'metacarpal2_lvs.vtp'.
# [warning] Couldn't find file 'index_proximal_lvs.vtp'.
# [warning] Couldn't find file 'index_medial_lvs.vtp'.
# [warning] Couldn't find file 'index_distal_lvs.vtp'.
# [warning] Couldn't find file 'metacarpal3_lvs.vtp'.
# [warning] Couldn't find file 'middle_proximal_lvs.vtp'.
# [warning] Couldn't find file 'middle_medial_lvs.vtp'.
# [warning] Couldn't find file 'middle_distal_lvs.vtp'.
# [warning] Couldn't find file 'metacarpal4_lvs.vtp'.
# [warning] Couldn't find file 'ring_proximal_lvs.vtp'.
# [warning] Couldn't find file 'ring_medial_lvs.vtp'.
# [warning] Couldn't find file 'ring_distal_lvs.vtp'.
# [warning] Couldn't find file 'metacarpal5_lvs.vtp'.
# [warning] Couldn't find file 'little_proximal_lvs.vtp'.
# [warning] Couldn't find file 'little_medial_lvs.vtp'.
# [warning] Couldn't find file 'little_distal_lvs.vtp'.
# [warning] Couldn't find file 'metacarpal1_lvs.vtp'.
# [warning] Couldn't find file 'thumb_proximal_lvs.vtp'.
# [warning] Couldn't find file 'thumb_distal_lvs.vtp'.

# %% [markdown]
# Get the musculotendon lengths for the desired range of motion for each muscle

# %%
import polars as pl

# Specify muscles to analyze and number of lengths
muscles = {
    'gaslat_r': 100,
    'bflh_r': 100,
    'soleus_r': 100,
}

lengths: dict[str, pl.DataFrame] = {}
for muscle_name, num_lengths in muscles.items():
    try:
        lengths[muscle_name] = graph.get_muscle_lengths_rom(
            muscle_names=[muscle_name],
            min_points=num_lengths
        )
    except Exception as e:
        print(f"Muscle {muscle_name} not found in the model: {e}")

# %% [markdown]
# Plot the musculotendon lengths with respect to the coordinates

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create comprehensive visualizations of musculotendon lengths vs coordinates
print("Creating coordinate-based visualizations:")
print("="*50)

# Let's examine the coordinate columns in more detail
coordinate_info = {}
for muscle_name, length_data in lengths.items():
    coords = [col for col in length_data.columns if col != muscle_name]
    coordinate_info[muscle_name] = coords
    print(f"{muscle_name}: {len(coords)} coordinates - {coords}")

# Find common and unique coordinates across muscles
all_coords = set()
for coords in coordinate_info.values():
    all_coords.update(coords)

print(f"\nAll unique coordinates: {sorted(list(all_coords))}")
print(f"Total number of unique coordinates: {len(all_coords)}")

# Create visualization strategy based on coordinate patterns
fig = plt.figure(figsize=(18, 12))

# Plot each muscle's MT length against its primary coordinates
subplot_rows = len(muscles)
subplot_cols = 4  # Show up to 4 most important coordinates per muscle

for muscle_idx, (muscle_name, length_data) in enumerate(lengths.items()):
    coords = coordinate_info[muscle_name]
    
    # Get the muscle length values
    mt_lengths = length_data.select(pl.col(muscle_name)).to_numpy().flatten()
    
    # Select the most varying coordinates (those with largest range)
    coord_ranges = {}
    for coord in coords:
        coord_values = length_data.select(pl.col(coord)).to_numpy().flatten()
        coord_ranges[coord] = np.max(coord_values) - np.min(coord_values)
    
    # Sort coordinates by their range (most varying first)
    sorted_coords = sorted(coord_ranges.items(), key=lambda x: x[1], reverse=True)
    top_coords = [coord for coord, _ in sorted_coords[:subplot_cols]]
    
    print(f"\n{muscle_name} - Top varying coordinates:")
    for coord, range_val in sorted_coords[:subplot_cols]:
        print(f"  {coord}: range = {range_val:.4f} rad")
    
    # Create subplots for this muscle's top coordinates
    for coord_idx, coord in enumerate(top_coords):
        plt.subplot(subplot_rows, subplot_cols, muscle_idx * subplot_cols + coord_idx + 1)
        
        coord_values = length_data.select(pl.col(coord)).to_numpy().flatten()
        
        # Create scatter plot with color-coding for MT length
        scatter = plt.scatter(coord_values, mt_lengths, c=mt_lengths, 
                            cmap='viridis', alpha=0.6, s=20)
        
        plt.xlabel(f'{coord} (rad)')
        plt.ylabel('MT Length (m)')
        plt.title(f'{muscle_name}\n{coord}')
        plt.grid(True, alpha=0.3)
        
        # Add colorbar for the first plot of each muscle
        if coord_idx == 0:
            cbar = plt.colorbar(scatter)
            cbar.set_label('MT Length (m)', rotation=270, labelpad=15)

plt.tight_layout()
plt.show()


# Show correlation between coordinates and MT lengths
print("\n" + "="*60)
print("COORDINATE-MT LENGTH CORRELATION ANALYSIS")
print("="*60)

correlation_data = []
for muscle_name, length_data in lengths.items():
    coords = coordinate_info[muscle_name]
    mt_lengths = length_data.select(pl.col(muscle_name)).to_numpy().flatten()
    
    print(f"\n{muscle_name}:")
    print("-" * 40)
    
    correlations = {}
    for coord in coords:
        coord_values = length_data.select(pl.col(coord)).to_numpy().flatten()
        
        # Calculate correlation
        correlation = np.corrcoef(coord_values, mt_lengths)[0, 1]
        correlations[coord] = correlation
        
        correlation_data.append({
            'muscle': muscle_name,
            'coordinate': coord,
            'correlation': correlation,
            'coord_range': np.max(coord_values) - np.min(coord_values)
        })
    
    # Sort by absolute correlation
    sorted_corrs = sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True)
    
    print("Top correlations (coordinate vs MT length):")
    for coord, corr in sorted_corrs[:5]:  # Show top 5
        print(f"  {coord:20s}: r = {corr:7.4f}")
# Out:
# Creating coordinate-based visualizations:
# ==================================================
# gaslat_r: 3 coordinates - ['subtalar_angle_r', 'ankle_angle_r', 'knee_angle_r']
# bflh_r: 4 coordinates - ['knee_angle_r', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r']
# soleus_r: 2 coordinates - ['subtalar_angle_r', 'ankle_angle_r']
#
# All unique coordinates: ['ankle_angle_r', 'hip_adduction_r', 'hip_flexion_r', 'hip_rotation_r', 'knee_angle_r', 'subtalar_angle_r']
# Total number of unique coordinates: 6
#
# gaslat_r - Top varying coordinates:
#   knee_angle_r: range = 2.4435 rad
#   ankle_angle_r: range = 1.7453 rad
#   subtalar_angle_r: range = 1.2217 rad
#
# bflh_r - Top varying coordinates:
#   hip_flexion_r: range = 2.6180 rad
#   knee_angle_r: range = 2.4435 rad
#   hip_adduction_r: range = 1.3963 rad
#   hip_rotation_r: range = 1.3963 rad
#
# soleus_r - Top varying coordinates:
#   ankle_angle_r: range = 1.7453 rad
#   subtalar_angle_r: range = 1.2217 rad
# ============================================================
# COORDINATE-MT LENGTH CORRELATION ANALYSIS
# ============================================================
#
# gaslat_r:
# ----------------------------------------
# Top correlations (coordinate vs MT length):
#   ankle_angle_r       : r =  0.7562
#   knee_angle_r        : r = -0.6442
#   subtalar_angle_r    : r = -0.0459
#
# bflh_r:
# ----------------------------------------
# Top correlations (coordinate vs MT length):
#   hip_flexion_r       : r =  0.8102
#   knee_angle_r        : r = -0.5237
#   hip_adduction_r     : r = -0.1829
#   hip_rotation_r      : r =  0.0447
#
# soleus_r:
# ----------------------------------------
# Top correlations (coordinate vs MT length):
#   ankle_angle_r       : r =  0.9919
#   subtalar_angle_r    : r = -0.0546

# %% [markdown]
# Optimize for tendon slack length

# %%
from src.tsl_optimization import optimize_fiber_length, ssdp, ssd
from src.muscle_params import calc_tsl
import opensim as osim
import numpy as np
import polars as pl

lm_norm_range = (0.4, 1.5)  # Normalized fiber length range
objectives = {'SSDP': ssdp,
            #   'SSD': ssd,
            #   'Var': lambda x: np.var(x),
            #   'Std': lambda x: np.std(x),
              }  # Objectives for optimization

muscle_data = {}
for muscle_name, lmt in lengths.items():
    muscle = graph.get_muscle(muscle_name)
    
    lm_opt = float(muscle.get_optimal_fiber_length())
    lm_range = lm_opt * np.asarray(lm_norm_range)
    alpha_opt = float(muscle.get_pennation_angle_at_optimal())
    lmt = np.clip(np.sort(np.unique(lmt.select(pl.col(muscle_name)))), 1e-6, None) # Ensure lmt is sorted, unique, and non-zero
    
    millard: osim.Millard2012EquilibriumMuscle = osim.Millard2012EquilibriumMuscle.safeDownCast(muscle)
    afl = millard.getActiveForceLengthCurve()
    pfl = millard.getFiberForceLengthCurve()
    tfl = millard.getTendonForceLengthCurve()
    
    muscle_data[muscle_name] = {
        'lm_opt': lm_opt, 
        'alpha_opt': alpha_opt,
        'lm_range': lm_range
    }
    for obj_name, obj_func in objectives.items():
        # Optimize fiber length using the specified objective function
        lm = optimize_fiber_length(lmt, lm_opt, alpha_opt, afl, pfl, tfl, lm_norm_range, objective=obj_func)
        tsl = calc_tsl(lmt, lm, lm_opt, alpha_opt, afl, pfl, tfl)
        muscle_data[muscle_name][obj_name] = {
            'tsl': tsl, 
            'lm': lm, 
            'min_force': np.zeros_like(lm),
            'max_force': np.zeros_like(lm)
        }

# %% [markdown]
# Calculate the force that would be produced with each tendon slack length at the respective musculotendon lengths

# %%
import polars as pl

activations = [0.01, 1.0]

for muscle_name, lmt in lengths.items():
    lmt = lmt.sort(pl.col(muscle_name))
    for obj_name in objectives.keys():
        for activation in activations:
            coord_vals = lmt.select(pl.exclude(muscle_name))
            for t, values in zip(range(len(lmt)), coord_vals.to_numpy()):
                muscle = graph.get_muscle(muscle_name)
                muscle.set_tendon_slack_length(muscle_data[muscle_name][obj_name]['tsl'][t])
                # print(f"Setting TSL for {muscle_name} at point {t}: {muscle_data[muscle_name][obj_name]['tsl'][t]:.4f} m")
                s = graph.osim_model.initSystem()
                muscle.setActivation(s, activation)
                for coord, val in zip(coord_vals.columns, values):
                    graph.get_coordinate(coord).setValue(s, val)
                graph.osim_model.equilibrateMuscles(s)                
                graph.osim_model.realizeDynamics(s)
                muscle = graph.get_muscle(muscle_name)
                force = muscle.getTendonForce(s)
                muscle_data[muscle_name][obj_name]['max_force' if activation == 1.0 else 'min_force'][t] = force

# %% [markdown]
# Get the musculotendon lengths for walking, squatting, and cutting motions.

# %%
def sto_to_df(file_path: str) -> tuple[pl.DataFrame, dict[str, str]]:
    """
    Reads a .sto or .mot file and returns a Polars DataFrame.

    Args:
        file_path (str): Path to the .sto or .mot file.

    Returns:
        tuple: A tuple containing a Polars DataFrame with the data and a dictionary with metadata.
    """
    # Read the header of the file to determine number of lines to skip
    file_metadata = {"name": "", "comments": []}
    lines_to_skip = 1
    with open(file_path, "r") as f:
        line = f.readline()
        if "=" in line:
            key, value = line.split("=", 1)
            if key and value:
                file_metadata[key.lower()] = value.strip()
            line = f.readline()  # Read the next line after the key-value pair
            lines_to_skip += 1
        elif not line.startswith("endheader"):
            file_metadata["name"] = line.strip()
            line = f.readline()  # Second line should start the key value pairs
            lines_to_skip += 1
        else:  # If the first line is 'endheader', do not enter the loop
            file_metadata["name"] = "Unnamed File"
        while line and not line.startswith("endheader"):
            line = line.strip()
            if "=" in line:
                key, value = line.split("=", 1)
                if key and value:
                    file_metadata[key.lower()] = value.strip()
            elif line:  # Treat as a comment or empty line
                file_metadata["comments"].append(line)
            line = f.readline()  # Read until 'endheader'
            lines_to_skip += 1

    df = pl.read_csv(
        file_path, separator="\t", skip_lines=lines_to_skip, truncate_ragged_lines=True
    )
    # Strip whitespace from columns
    df = df.with_columns(
        [
            pl.col(col).cast(pl.String).str.strip_chars().cast(pl.Float64)
            for col in df.columns
        ]
    )
    return df, file_metadata

# %%
squatting_ik = 'data/Squatting_IK.mot'
cutting_ik = 'data/Cutting_IK.mot'
walking_ik = 'data/Walking_IK.mot'

squatting_df, squatting_meta = sto_to_df(squatting_ik)
cutting_df, cutting_meta = sto_to_df(cutting_ik)
walking_df, walking_meta = sto_to_df(walking_ik)

motion_data = {
    'squatting': {
        'df': squatting_df,
        'muscles':{}
    },
    'cutting': {
        'df': cutting_df,
        'muscles':{}
    },
    'walking': {
        'df': walking_df,
        'muscles':{}
    }
}

for muscle_name in muscles.keys():
    coords = graph.muscle_coords[muscle_name]
    for motion, motion_info in motion_data.items():
        coord_vals = motion_info['df'].select(pl.col(coords)) * 2 * np.pi / 180
        
        # Get the muscle lengths for this motion
        muscle_lengths = graph.get_muscle_lengths_from_data([muscle_name], coord_vals)
        
        motion_data[motion]['muscles'][muscle_name] = {
            'lengths': muscle_lengths,
            'min': muscle_lengths.select(pl.col(muscle_name)).min().item(),
            'max': muscle_lengths.select(pl.col(muscle_name)).max().item(),
        }

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Rajagopal's TSL estimates for comparison
rajagopal_tsl = {
    'gaslat_r': 0.374,
    'bflh_r': 0.33250000000000002,
    'soleus_r': 0.28134999999999999,
}

muscle_titles = {
    'gaslat_r': 'Lateral Gastrocnemius',
    'bflh_r': 'Biceps Femoris Long Head',
    'soleus_r': 'Soleus'
}

# Colors and markers for different objectives
objective_colors = ['blue', 'red', 'green', 'orange']
markers = ['o', 's', '^', 'D']

motion_colors = ['orange', 'lightgreen', 'lightcoral']

# Plot each muscle in a separate figure
muscle_names = list(muscles.keys())

# Create shared legend elements (we'll use the first muscle to generate legend handles)
legend_handles = []
legend_labels = []

for idx, muscle_name in enumerate(muscle_names):
    # Create a new figure for each muscle
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax2 = ax.twinx()
    
    # Get MT lengths used in optimization
    lmt_data = lengths[muscle_name].select(pl.col(muscle_name)).to_numpy().flatten()
    lmt_unique = np.clip(np.sort(np.unique(lmt_data)), 1e-6, None)
    
    # Plot TSL estimates for each objective
    for j, objective in enumerate(objectives.keys()):
        if objective not in muscle_data[muscle_name]:
            print(f"Warning: Objective '{objective}' not found for muscle '{muscle_name}'. Skipping.")
            continue
        tsl_result = muscle_data[muscle_name][objective]['tsl']

        scatter = ax.scatter(lmt_unique, tsl_result, color=objective_colors[j], marker=markers[j], 
                    s=30, alpha=0.7, label=f'{objective} TSL')
        
        min_force = muscle_data[muscle_name][objective]['min_force']
        max_force = muscle_data[muscle_name][objective]['max_force']
        fill = ax2.fill_between(lmt_unique, min_force, max_force, color=objective_colors[j], alpha=0.2, 
                        label=f'{objective} Force Range')
        
        # Collect legend handles for the first muscle only
        if idx == 0:
            legend_handles.extend([scatter, fill])
            legend_labels.extend([f'{objective} TSL', f'{objective} Force Range'])

    if muscle_name in rajagopal_tsl:
        tsl_value = rajagopal_tsl[muscle_name]
        line = ax.axhline(y=tsl_value, color='black', linestyle=':', linewidth=3,
                   label='Rajagopal TSL')
        
        # Annotate the Rajagopal TSL value on the plot
        ax.annotate(f'{tsl_value:.4f} m', 
                   xy=(lmt_unique.mean(), tsl_value), 
                   xytext=(10, 20), textcoords='offset points',
                   bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=1.0),
                   arrowprops=dict(arrowstyle='->', color='black'),
                   fontsize=10, ha='left')
        
        # Add to legend for first muscle only
        if idx == 0:
            legend_handles.append(line)
            legend_labels.append('Rajagopal TSL')
        
    # Shade regions for the lengths in the motion data
    for motion_idx, (motion, motion_info) in enumerate(motion_data.items()):
        muscle_lengths = motion_info['muscles'].get(muscle_name, {}).get('lengths', None)
        if muscle_lengths is not None:
            min_length = muscle_lengths.select(pl.col(muscle_name)).min().item()
            max_length = muscle_lengths.select(pl.col(muscle_name)).max().item()
            span = ax.axvspan(min_length, max_length, color=motion_colors[motion_idx], alpha=0.3, 
                       label=f'{motion.title()} Length Range')
            
            # Add to legend for first muscle only
            if idx == 0:
                legend_handles.append(span)
                legend_labels.append(f'{motion.title()} Length Range')
        
    ax2.set_ylabel('Tendon Force (N)', color='black')
    ax2.tick_params(axis='y', labelcolor='black')
    
    ax.set_xlabel('Musculotendon Length (m)')
    ax.set_ylabel('Tendon Slack Length (m)')
    
    # Use LaTeX formatting for subscript and superscript in the title
    fig.suptitle(
        # f'Tendon Slack Length Estimates vs Musculotendon Lengths\n'
        rf'{muscle_titles.get(muscle_name, muscle_name).title()} (n={len(lmt_unique)} points):'
        '\n'
        r'$l^{m}_{o}$ = '
        f'{muscle_data[muscle_name]["lm_opt"]:.4f} m, '
        r'$\alpha_{o}$ = '
        f'{muscle_data[muscle_name]["alpha_opt"]:.2f} rad, '
        r'$l^{m}_{range}$ = '
        f'{muscle_data[muscle_name]["lm_range"][0]:.4f} - {muscle_data[muscle_name]["lm_range"][1]:.4f} m, '
        r'$\tilde{l}^{m}_{range}$ =' f'{lm_norm_range}',
        fontsize=14
    )
    
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Create a separate figure for the shared legend
if legend_handles:
    fig_legend, ax_legend = plt.subplots(figsize=(12, 2))
    ax_legend.axis('off')  # Hide the axes
    
    # Create the legend
    legend = ax_legend.legend(legend_handles, legend_labels, 
                             loc='center', ncol=len(legend_handles)//2, 
                             fontsize=12, frameon=True)
    legend.get_frame().set_facecolor('white')
    legend.get_frame().set_alpha(0.9)
    
    plt.title('Shared Legend for TSL Analysis Plots', fontsize=14, pad=20)
    plt.tight_layout()
    plt.show()

# Create summary statistics for each muscle-objective combination
print("\n" + "="*80)
print("DETAILED TSL ESTIMATES ANALYSIS")
print("="*80)

summary_data = []
for muscle_name in muscle_names:
    lmt_data = lengths[muscle_name].select(pl.col(muscle_name)).to_numpy().flatten()
    lmt_unique = np.clip(np.sort(np.unique(lmt_data)), 1e-6, None)
    
    print(f"\n{muscle_name.upper()}:")
    print("-" * 50)
    print(f"MT Length Range: {lmt_unique.min():.4f} - {lmt_unique.max():.4f} m")
    print(f"Number of MT Length Points: {len(lmt_unique)}")
    
    for objective in objectives.keys():
        tsl_result = muscle_data[muscle_name][objective]['tsl']
        
        if hasattr(tsl_result, '__len__') and len(tsl_result) > 1:
            tsl_array = np.array(tsl_result)
            print(f"\n{objective}:")
            print(f"  Number of TSL estimates: {len(tsl_array)}")
            print(f"  TSL range: {tsl_array.min():.4f} - {tsl_array.max():.4f} m")
            print(f"  TSL mean ± std: {tsl_array.mean():.4f} ± {tsl_array.std():.4f} m")
            print(f"  TSL coefficient of variation: {tsl_array.std()/tsl_array.mean()*100:.2f}%")
            
            # Add to summary data
            if len(tsl_result) == len(lmt_unique):
                for mt_val, tsl_val in zip(lmt_unique, tsl_result):
                    summary_data.append({
                        'Muscle': muscle_name,
                        'Objective': objective,
                        'MT_Length': mt_val,
                        'TSL_Estimate': tsl_val
                    })
        else:
            print(f"\n{objective}: Single value = {float(tsl_result):.4f} m")

# Convert to DataFrame for easier analysis
if summary_data:
    df_summary = pd.DataFrame(summary_data)
    print(f"\nTotal TSL-MT data points collected: {len(df_summary)}")
    
    # Show correlation analysis
    print("\nCorrelation between MT Length and TSL estimates:")
    for muscle_name in muscle_names:
        summary_data = df_summary[df_summary['Muscle'] == muscle_name]
        if len(summary_data) > 1:
            correlation = summary_data['MT_Length'].corr(summary_data['TSL_Estimate'])
            print(f"  {muscle_name}: r = {correlation:.4f}")
else:
    print("\nNo array-based TSL estimates found for detailed analysis.")
# Out:
# ================================================================================
# DETAILED TSL ESTIMATES ANALYSIS
# ================================================================================
#
# GASLAT_R:
# --------------------------------------------------
# MT Length Range: 0.3561 - 0.4815 m
# Number of MT Length Points: 125
#
# SSDP:
#   Number of TSL estimates: 125
#   TSL range: 0.3326 - 0.3790 m
#   TSL mean ± std: 0.3571 ± 0.0068 m
#   TSL coefficient of variation: 1.89%
#
# BFLH_R:
# --------------------------------------------------
# MT Length Range: 0.3307 - 0.5238 m
# Number of MT Length Points: 256
#
# SSDP:
#   Number of TSL estimates: 256
#   TSL range: 0.2956 - 0.3784 m
#   TSL mean ± std: 0.3414 ± 0.0125 m
#   TSL coefficient of variation: 3.66%
#
# SOLEUS_R:
# --------------------------------------------------
# MT Length Range: 0.2857 - 0.3521 m
# Number of MT Length Points: 100
#
# SSDP:
#   Number of TSL estimates: 100
#   TSL range: 0.2792 - 0.2881 m
#   TSL mean ± std: 0.2836 ± 0.0013 m
#   TSL coefficient of variation: 0.47%
#
# Total TSL-MT data points collected: 481
#
# Correlation between MT Length and TSL estimates:
#   gaslat_r: r = 0.7613
#   bflh_r: r = 0.7670
#   soleus_r: r = 0.6232
